# %% [markdown]
# ## EDA

# %% [markdown]
# ##### LIBRERIA

# %%
import pandas as pd

# %% [markdown]
# ##### DS

# %%
URL = "https://breathecode.herokuapp.com/asset/internal-link?id=930&path=diabetes.csv"
ds = pd.read_csv(URL, sep=",")
ds.to_csv('../data/raw/early_ds_raw.csv', index=False)
