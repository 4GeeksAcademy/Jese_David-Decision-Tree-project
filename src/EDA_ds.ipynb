# %% [markdown]
# #  EDA

# %%
#LIBRERIAS
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import utils as eda

# %%
#ARCHIVO + TARGET
URL = "../data/processed/ds_clean.csv"
ds_clean = pd.read_csv(URL)
target = 'Outcome'

# %% [markdown]
# ___

# %% [markdown]
# #### ANALISIS MULTIVARIABLE
